# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\USER\Desktop\Football-XAI-suite\data\master_football_xai_dataset.csv")

# %%
df.head()
# Out:
#    player_id        player_name  age nationality  height_cm  weight_kg  \
# 0          1       Lionel Messi   24      France        191         64
# 1          2  Cristiano Ronaldo   32    Paraguay        184         81
# 2          3      Kylian Mbappé   28       Japan        187         92
# 3          4     Erling Haaland   25     England        197         87
# 4          5             Neymar   24       Japan        186         62
#
#              club_name position  matches_played  minutes_played  ...  \
# 0          Inter Miami  Forward              28            1925  ...
# 1             Al-Nassr  Forward              47            3217  ...
# 2  Paris Saint-Germain  Forward               4             293  ...
# 3      Manchester City  Forward              57            3897  ...
# 4             Al-Hilal  Forward              34            2333  ...
#
#    recovery_time_hours  muscle_strength_score  injury_risk_score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1993 entries, 0 to 1992
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    1993 non-null   int64
#  1   player_name                  1993 non-null   object
#  2   age                          1993 non-null   int64
#  3   nationality                  1993 non-null   object
#  4   height_cm                    1993 non-null   int64
#  5   weight_kg                    1993 non-null   int64
#  6   club_name                    1993 non-null   object
#  7   position                     1993 non-null   object
#  8   matches_played               1993 non-null   int64
#  9   minutes_played               1993 non-null   int64
#  10  goals                        1993 non-null   int64
#  11  assists                      1993 non-null   int64
#  12  shots_on_target              1993 non-null   int64
# ...

# %%
df.describe()
# Out:
#          player_id          age    height_cm    weight_kg  matches_played  \
# count  1993.000000  1993.000000  1993.000000  1993.000000     1993.000000
# mean    997.000000    26.813347   183.512795    81.739589       30.123934
# std     575.473863     5.551627     7.039330     8.927470       17.711295
# min       1.000000    18.000000   160.000000    52.000000        0.000000
# 25%     499.000000    22.000000   179.000000    76.000000       15.000000
# 50%     997.000000    27.000000   184.000000    82.000000       30.000000
# 75%    1495.000000    32.000000   189.000000    88.000000       46.000000
# max    1993.000000    36.000000   208.000000   118.000000       60.000000
#
#        minutes_played        goals      assists  shots_on_target  \
# count     1993.000000  1993.000000  1993.000000      1993.000000
# mean      2069.427496     1.457602     0.447065         1.381836
# std       1204.368028     3.123035     1.001170         2.559181
# ...
